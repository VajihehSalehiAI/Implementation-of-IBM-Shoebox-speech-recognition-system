# %%
# requirement packages
# !pip install git+https://github.com/huggingface/datasets.git
# !pip install git+https://github.com/huggingface/transformers.git
# !pip install torchaudio
# !pip install librosa
# !pip install jiwer
# !pip install hazm
# Out:
# Collecting git+https://github.com/huggingface/datasets.git
#   Cloning https://github.com/huggingface/datasets.git to /tmp/pip-req-build-qnf1skbt
#   Running command git clone -q https://github.com/huggingface/datasets.git /tmp/pip-req-build-qnf1skbt
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets==1.11.1.dev0) (1.19.5)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.11.1.dev0) (3.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.11.1.dev0) (0.3.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.11.1.dev0) (1.1.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.11.1.dev0) (2.23.0)
# Collecting tqdm>=4.62.1
#   Downloading tqdm-4.62.2-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 441 kB/s
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 15.5 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets==1.11.1.dev0) (0.70.12.2)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2021.7.0-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 65.5 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 53.9 MB/s
# Collecting huggingface_hub<0.1.0,>=0.0.14
#   Downloading huggingface_hub-0.0.15-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.5 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets==1.11.1.dev0) (21.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.7/dist-packages (from datasets==1.11.1.dev0) (4.6.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface_hub<0.1.0,>=0.0.14->datasets==1.11.1.dev0) (3.0.12)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface_hub<0.1.0,>=0.0.14->datasets==1.11.1.dev0) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets==1.11.1.dev0) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.11.1.dev0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.11.1.dev0) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.11.1.dev0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.11.1.dev0) (2.10)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==1.11.1.dev0) (21.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142 kB)
#      |████████████████████████████████| 142 kB 69.5 MB/s
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 69.3 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib_metadata->datasets==1.11.1.dev0) (3.5.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.11.1.dev0) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.11.1.dev0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets==1.11.1.dev0) (1.15.0)
# Building wheels for collected packages: datasets
#   Building wheel for datasets (setup.py) ... done
#   Created wheel for datasets: filename=datasets-1.11.1.dev0-py3-none-any.whl size=267132 sha256=bca1076c0b54c94496ca72e4b89bf310101b985fd8cb905f5fa9d32087a7fd22
#   Stored in directory: /tmp/pip-ephem-wheel-cache-29vj0p2f/wheels/cc/33/c1/2cacc415b23189a83908e45db67381ba26175ef1e8aa9062aa
# Successfully built datasets
# Installing collected packages: multidict, yarl, async-timeout, tqdm, fsspec, aiohttp, xxhash, huggingface-hub, datasets
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.0
#     Uninstalling tqdm-4.62.0:
#       Successfully uninstalled tqdm-4.62.0
# Successfully installed aiohttp-3.7.4.post0 async-timeout-3.0.1 datasets-1.11.1.dev0 fsspec-2021.7.0 huggingface-hub-0.0.15 multidict-5.1.0 tqdm-4.62.2 xxhash-2.0.2 yarl-1.6.3
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-vfeua89g
#   Running command git clone -q https://github.com/huggingface/transformers.git /tmp/pip-req-build-vfeua89g
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 8.7 MB/s
# Requirement already satisfied: huggingface-hub>=0.0.12 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0.dev0) (0.0.15)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0.dev0) (3.0.12)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0.dev0) (4.6.4)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 42.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0.dev0) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0.dev0) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0.dev0) (21.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0.dev0) (2.23.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 34.0 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0.dev0) (4.62.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.12->transformers==4.10.0.dev0) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.10.0.dev0) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.10.0.dev0) (3.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.0.dev0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.0.dev0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.0.dev0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.0.dev0) (2021.5.30)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.10.0.dev0) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.10.0.dev0) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.10.0.dev0) (1.15.0)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (PEP 517) ... done
#   Created wheel for transformers: filename=transformers-4.10.0.dev0-py3-none-any.whl size=2677591 sha256=59b1a446c3c8f7d86f6ca350fdcda9465d7217a9e045f66b6633a3930e13c9e5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3kqlks0m/wheels/90/a5/44/6bcd83827c8a60628c5ad602f429cd5076bcce5f2a90054947
# Successfully built transformers
# Installing collected packages: tokenizers, sacremoses, pyyaml, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed pyyaml-5.4.1 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.10.0.dev0
# Collecting torchaudio
#   Downloading torchaudio-0.9.0-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 8.2 MB/s
# Requirement already satisfied: torch==1.9.0 in /usr/local/lib/python3.7/dist-packages (from torchaudio) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.0->torchaudio) (3.7.4.3)
# Installing collected packages: torchaudio
# Successfully installed torchaudio-0.9.0
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.19.5)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.22.2.post1)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.4.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.4.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (57.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Collecting jiwer
#   Downloading jiwer-2.2.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from jiwer) (1.19.5)
# Collecting python-Levenshtein
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 3.7 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein->jiwer) (57.4.0)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=149865 sha256=99dd96b9838251983114fae2fdda91445d5f56e60d71b8a23bbd459b4e2b4331
#   Stored in directory: /root/.cache/pip/wheels/05/5f/ca/7c4367734892581bb5ff896f15027a932c551080b2abd3e00d
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein, jiwer
# Successfully installed jiwer-2.2.0 python-Levenshtein-0.12.2
# Collecting hazm
#   Downloading hazm-0.7.0-py3-none-any.whl (316 kB)
#      |████████████████████████████████| 316 kB 8.6 MB/s
# Collecting libwapiti>=0.2.1
#   Downloading libwapiti-0.2.1.tar.gz (233 kB)
#      |████████████████████████████████| 233 kB 54.1 MB/s
# Collecting nltk==3.3
#   Downloading nltk-3.3.0.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 21.5 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.3->hazm) (1.15.0)
# Building wheels for collected packages: nltk, libwapiti
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.3-py3-none-any.whl size=1394486 sha256=a89cc23b8d94a611dd76e90846c4f65306c059d58bcadd5b0c09521b0530e888
#   Stored in directory: /root/.cache/pip/wheels/9b/fd/0c/d92302c876e5de87ebd7fc0979d82edb93e2d8d768bf71fac4
#   Building wheel for libwapiti (setup.py) ... done
#   Created wheel for libwapiti: filename=libwapiti-0.2.1-cp37-cp37m-linux_x86_64.whl size=154875 sha256=dd195af770c4b7ec4c8d8ff293b668d28534f57a6f4322664c2bef812f57c688
#   Stored in directory: /root/.cache/pip/wheels/ab/b2/5b/0fe4b8f5c0e65341e8ea7bb3f4a6ebabfe8b1ac31322392dbf
# Successfully built nltk libwapiti
# Installing collected packages: nltk, libwapiti, hazm
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# Successfully installed hazm-0.7.0 libwapiti-0.2.1 nltk-3.3

# %%
import librosa
import torch
import torchaudio
import soundfile as sf
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
from datasets import load_dataset

from IPython.display import Audio
from scipy.io import wavfile
import numpy as np

import IPython.display as ipd

# %%
file_name = 'test3.wav'

# %%
Audio(file_name)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data = wavfile.read(file_name)

print('Sample rate:',data[0],'Hz')
print('Total time:',len(data[1])/data[0],'s')

input_audio, _ = librosa.load(file_name, sr=16000)
input_audio.dtype
# Out:
# Sample rate: 44100 Hz
# Total time: 11.153628117913833 s
# dtype('float32')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
processor = Wav2Vec2Processor.from_pretrained("m3hrdadfi/wav2vec2-large-xlsr-persian")
model = Wav2Vec2ForCTC.from_pretrained("m3hrdadfi/wav2vec2-large-xlsr-persian").to(device)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
input_values = processor(input_audio, return_tensors="pt").input_values
logits = model(input_values).logits
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)[0]
print(transcription)
# Out:
# It is strongly recommended to pass the ``sampling_rate`` argument to this function.Failing to do so can result in silent errors that might be hard to debug.
# سه یک پنج من ها سه یک پنج

# %%
print(type(transcription))
# Out:
# <class 'str'>

# %%
import sys, os, difflib, argparse
from datetime import datetime, timezone
import keyword
#difflib.get_close_matches('appel', ['ape', 'apple', 'peach', 'puppy'])
#get_close_matches('wheel', keyword.kwlist)
sentense1 = difflib.get_close_matches('سپر', ['صفر', 'یک', 'دو', 'سه', 'چهار', 'پنج', 'شش', 'هفت', 'هشت', 'نه', 'بعلاوه', 'منها', 'ضرب', 'تقسیم'],cutoff=0.3,n=4)
sentense2 = difflib.get_close_matches('دعلاوه', ['صفر', 'یک', 'دو', 'سه', 'چهار', 'پنج', 'شش', 'هفت', 'هشت', 'نه', 'بعلاوه', 'منها', 'ضرب', 'تقسیم'],cutoff=0.3,n=1)
sentense3 = difflib.get_close_matches('س', ['صفر', 'یک', 'دو', 'سه', 'چهار', 'پنج', 'شش', 'هفت', 'هشت', 'نه', 'بعلاوه', 'منها', 'ضرب', 'تقسیم'],cutoff=0.3,n=1)
sentense4 = difflib.get_close_matches('بهعلابه', ['صفر', 'یک', 'دو', 'سه', 'چهار', 'پنج', 'شش', 'هفت', 'هشت', 'نه', 'بعلاوه', 'منها', 'ضرب', 'تقسیم'],cutoff=0.3,n=1)
sentense5 = difflib.get_close_matches('من ها', ['صفر', 'یک', 'دو', 'سه', 'چهار', 'پنج', 'شش', 'هفت', 'هشت', 'نه', 'بعلاوه', 'منها', 'ضرب', 'تقسیم'],cutoff=0.3,n=1)
sentense6 = difflib.get_close_matches('بهعلاوه', ['صفر', 'یک', 'دو', 'سه', 'چهار', 'پنج', 'شش', 'هفت', 'هشت', 'نه', 'بعلاوه', 'منها', 'ضرب', 'تقسیم'],cutoff=0.3,n=1)
#print(sentense1)
a=str(sentense1[3])
b=str(sentense2[0])
c=str(sentense3[0])
d=str(sentense4[0])
e=str(sentense5[0])
f=str(sentense6[0])
print(c)
if 'سپر' in transcription:
    transcription = transcription.replace('سپر',a,4)
if 'دعلاوه' in transcription:
    transcription = transcription.replace('دعلاوه',b,2)
if 'س' in transcription and 'سه' not in transcription:
    transcription = transcription.replace('س',c,2)
if 'بهعلابه' in transcription:
    transcription = transcription.replace('بهعلابه',d,2)
if 'من ها' in transcription:
    transcription = transcription.replace('من ها',e,2)
if 'بهعلاوه' in transcription:
    transcription = transcription.replace('بهعلاوه',f,2)

  

  
print(transcription)
# Out:
# سه
# سه یک پنج منها سه یک پنج

# %%
split4= transcription.split(' ')
print(split4)
mydict = {'صفر':0,'یک':1,'دو':2,'سه':3,'چهار':4,'پنج':5,'شش':6,'هفت':7,'هشت':8,'نه':9,'بعلاوه':'+','منها':'-','ضرب':'*','تقسیم':'/'}
print(mydict['تقسیم'])
amalgar = ['بعلاوه','منها','ضرب','تقسیم']
for char in amalgar:
  if char in split4:
    x = split4.index(char)
    print(x)
adadaval=split4[0:x]
print(adadaval)
amalgar=mydict[split4[x]]
print(amalgar)
adaddovom=split4[x+1:len(split4)]
print(adaddovom)
# Out:
# ['سه', 'یک', 'پنج', 'منها', 'سه', 'یک', 'پنج']
# /
# 3
# ['سه', 'یک', 'پنج']
# -
# ['سه', 'یک', 'پنج']

# %%
str1=''
i = range(len(adadaval))
for char in i:
  a = mydict[adadaval[char]]
  str1 = str1 + str(a)
str1 = int(str1)
print(str1)
# Out:
# 315

# %%
str2=''
i = range(len(adaddovom))
for char in i:
  b = mydict[adaddovom[char]]
  str2 = str2 + str(b)
str2 = int(str2)
print(str2)
# Out:
# 315

# %%
print(str1)
print(amalgar)
print(str2)
# Out:
# 315
# -
# 315

# %%
num1 = int(str1)
num2 = int(str2)
if amalgar== '+':
  natije = num1+num2
elif amalgar== '-':
  natije = num1-num2
elif amalgar== '*':
  natije = num1*num2
elif amalgar== '/':
  natije = num1/num2
else:
  print("error")
print(natije)
# Out:
# 0

# %%
mydictamalgar = {'+':'بعلاوه','-':'منها','*':'ضرب','/':'تقسیم'}

# %%
# !pip install 'setuptools>=36.2.1'
# !pip install num2fawords
from num2fawords import words, ordinal_words
num1 = words(str1)
num2 = words(str2)
natije = words(natije)
print(num1)
print(num2)
print(natije)
mydictamalgar[amalgar]
print(type(num1))
print(type(mydictamalgar[amalgar]))
matn = num1 + ' ' + mydictamalgar[amalgar]+ ' ' + num2 + ' '+ 'برابر است با' + ' ' + natije
print(matn)
# Out:
# Requirement already satisfied: setuptools>=36.2.1 in /usr/local/lib/python3.7/dist-packages (57.4.0)
# Requirement already satisfied: num2fawords in /usr/local/lib/python3.7/dist-packages (1.1)
# سیصد و پانزده
# سیصد و پانزده
# صفر
# <class 'str'>
# <class 'str'>
# سیصد و پانزده منها سیصد و پانزده برابر است با صفر

# %%
phone_dir1 = './phonems'
phone_dir2 = './phonems2'

import numpy as np
import os
osjoin = os.path.join
phones = {}

    
for ph in os.listdir(phone_dir1):
    if not os.path.isdir(ph):
      print(ph)
      y, sr = librosa.load(osjoin(phone_dir1, ph), sr=16000, mono=True)
      phones[os.path.basename(ph)[:-4]] = y

for ph in os.listdir(phone_dir2):
    if not os.path.isdir(ph):
      print(ph)
      y, sr = librosa.load(osjoin(phone_dir2, ph), sr=16000, mono=True)
      phones[os.path.basename(ph)[:-4]] = y
    
phones[' '] = np.zeros(2000)
# Out:
# j.wav
# t.wav
# a.wav
# d.wav
# n.wav
# q.wav
# C.wav
# r.wav
# u.wav
# o.wav
# k.wav
# z.wav
# b.wav
# h.wav
# f.wav
# e.wav
# y.wav
# x.wav
# m.wav
# l.wav
# v.wav
# s.wav
# g.wav
# i.wav
# p.wav
# S.wav
# A.wav
# C.wav
# Z.wav
# _.wav

# %%
phones.keys()
# Out:
# dict_keys(['j', 't', 'a', 'd', 'n', 'q', 'C', 'r', 'u', 'o', 'k', 'z', 'b', 'h', 'f', 'e', 'y', 'x', 'm', 'l', 'v', 's', 'g', 'i', 'p', 'S', 'A', 'Z', '_', ' '])

# %%
import re
# !pip install hazm
from __future__ import unicode_literals
from hazm import *
#matn='چهارصد و هفتاد و شش بعلاوه دویست و ده برابر است با ششصد و هشتاد و شش'
normalizer = Normalizer()
normal1 = normalizer.normalize(re.sub(r'\u200c', ' ',matn ))
print(normal1)
# Out:
# Requirement already satisfied: hazm in /usr/local/lib/python3.7/dist-packages (0.7.0)
# Requirement already satisfied: libwapiti>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from hazm) (0.2.1)
# Requirement already satisfied: nltk==3.3 in /usr/local/lib/python3.7/dist-packages (from hazm) (3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.3->hazm) (1.15.0)
# سیصد و پانزده منها سیصد و پانزده برابر است با صفر

# %%
# !pip install PersianG2p
# !pip install librosa
# !pip install soundfile
import matplotlib.pyplot as plt
import numpy as np
import soundfile as sf
from PersianG2p import Persian_g2p_converter

PersianG2Pconverter = Persian_g2p_converter(use_large = True)
input_text = PersianG2Pconverter.transliterate(normal1, tidy = False)
print(input_text)
input_text = str(input_text)
print(type(input_text))
# Out:
# Requirement already satisfied: PersianG2p in /usr/local/lib/python3.7/dist-packages (0.3.2)
# Requirement already satisfied: num2fawords in /usr/local/lib/python3.7/dist-packages (from PersianG2p) (1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from PersianG2p) (1.19.5)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from PersianG2p) (2.1.0)
# Requirement already satisfied: hazm in /usr/local/lib/python3.7/dist-packages (from PersianG2p) (0.7.0)
# Requirement already satisfied: nltk==3.3 in /usr/local/lib/python3.7/dist-packages (from hazm->PersianG2p) (3.3)
# Requirement already satisfied: libwapiti>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from hazm->PersianG2p) (0.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.3->hazm->PersianG2p) (1.15.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.4.0)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.19.5)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.22.2.post1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (2021.5.30)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile) (2.20)
# sisad  v a  pAnzdah menhA sisad  v a  pAnzdah  b a r A b a r   a s t   b A   s e f r
# <class 'str'>

# %%
input_text1 = input_text.replace("?", "_")
print(input_text1)
# Out:
# sisad  v a  pAnzdah menhA sisad  v a  pAnzdah  b a r A b a r   a s t   b A   s e f r

# %%
audio = np.concatenate([phones[i] for i in input_text1])
# audio = librosa.effects.time_stretch(audio, 1.5)
sf.write('test3output.wav', audio, 16000)

# %%
Audio('test3output.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
